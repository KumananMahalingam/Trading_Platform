# %%
pip install yfinance pandas ta openpyxl
# Out:
# Requirement already satisfied: yfinance in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (0.2.65)
# Requirement already satisfied: pandas in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (2.3.2)
# Requirement already satisfied: ta in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (0.11.0)
# Requirement already satisfied: openpyxl in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (3.1.5)
# Requirement already satisfied: pytz>=2022.5 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: numpy>=1.16.5 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from yfinance) (2.2.6)
# Requirement already satisfied: peewee>=3.16.2 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: requests>=2.31 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: platformdirs>=2.0.0 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from yfinance) (4.4.0)
# Requirement already satisfied: multitasking>=0.0.7 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from yfinance) (4.13.5)
# Requirement already satisfied: websockets>=13.0 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: protobuf>=3.19.0 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from yfinance) (6.32.0)
# Requirement already satisfied: frozendict>=2.3.4 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: curl_cffi>=0.7 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: certifi>=2024.2.2 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from curl_cffi>=0.7->yfinance) (2025.8.3)
# Requirement already satisfied: cffi>=1.12.0 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: six>=1.5 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /home/kumananm/myproject/my_virtual_env/lib/python3.10/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd
import ta
from openpyxl import load_workbook
from openpyxl.styles import Font

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

companies = {
    "AAPL": "Apple",
    "HSBC": "HSBC",
    "PEP": "Pepsi",
    "TM": "Toyota",
    "TCEHY": "Tencent"
}

start_date = "2016-05-01"
end_date = "2024-05-08"

frames = []

for ticker, name in companies.items():
    df = yf.download(ticker, start=start_date, end=end_date)

    if isinstance(df.columns, pd.MultiIndex):
        new_columns = []
        for col in df.columns:
            if isinstance(col, tuple):
                new_columns.append("_".join([str(c) for c in col]).strip())
            else:
                new_columns.append(col)
        df.columns = new_columns

    df = df.reset_index()
    df["Company"] = name
    df = df.sort_values("Date").copy()

    close_col = next((col for col in df.columns if "Close" in col), "Close")
    volume_col = next((col for col in df.columns if "Volume" in col), "Volume")

    close = df[close_col].squeeze()
    close.index = df.index
    volume = df[volume_col].squeeze()
    volume.index = df.index

    df["SMA_5"] = ta.trend.SMAIndicator(close=close, window=5).sma_indicator()
    df["SMA_20"] = ta.trend.SMAIndicator(close=close, window=20).sma_indicator()
    df["EMA_10"] = ta.trend.EMAIndicator(close=close, window=10).ema_indicator()

    df["Momentum_3"] = ta.momentum.ROCIndicator(close=close, window=3).roc()
    df["Momentum_10"] = ta.momentum.ROCIndicator(close=close, window=10).roc()

    df["RSI_14"] = ta.momentum.RSIIndicator(close=close, window=14).rsi()

    macd = ta.trend.MACD(close=close, window_slow=26, window_fast=12, window_sign=9)
    df["MACD"] = macd.macd()
    df["MACD_Signal"] = macd.macd_signal()

    bb = ta.volatility.BollingerBands(close=close, window=20, window_dev=2)
    df["BB_Upper"] = bb.bollinger_hband()
    df["BB_Lower"] = bb.bollinger_lband()

    df["OBV"] = ta.volume.OnBalanceVolumeIndicator(close=close, volume=volume).on_balance_volume()

    frames.append(df)

combined_df = pd.concat(frames, ignore_index=True)
combined_df = combined_df.sort_values(["Company", "Date"])

indicator_cols = ["SMA_5","SMA_20","EMA_10","Momentum_3","Momentum_10","RSI_14",
                  "MACD","MACD_Signal","BB_Upper","BB_Lower","OBV"]
original_cols = [col for col in combined_df.columns if col not in indicator_cols]

combined_df = combined_df[original_cols + indicator_cols]

output_file = "combined_technical_indicators.xlsx"
combined_df.to_excel(output_file, index=False, engine='openpyxl')

wb = load_workbook(output_file)
ws = wb.active

for cell in ws[1]:
    cell.font = Font(bold=True)

for column_cells in ws.columns:
    max_length = 0
    column_letter = column_cells[0].column_letter
    for cell in column_cells:
        if cell.value:
            max_length = max(max_length, len(str(cell.value)))
    ws.column_dimensions[column_letter].width = max_length + 2

wb.save(output_file)
print(f"Data saved and formatted in {output_file}")
# Out:
# /tmp/ipykernel_3549/3120697970.py:19: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_3549/3120697970.py:19: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_3549/3120697970.py:19: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_3549/3120697970.py:19: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_3549/3120697970.py:19: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Data saved and formatted in combined_technical_indicators.xlsx
